# %%
#  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
from langchain_community.document_loaders import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os 
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import SKLearnVectorStore
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import

# %%
urls =['https://www.jeuneafrique.com/feed/']
docs =[WebBaseLoader(url).load() for url in urls]
docs_list= [item for sublist in docs for item in sublist]
print(docs_list)
# Out:
# [Document(metadata={'source': 'https://www.jeuneafrique.com/feed/', 'title': 'Jeune Afrique Feed - Contents - Jeune Afrique'}, page_content='\n\n\nJeune Afrique Feed - Contents - Jeune Afrique \nhttps://www.jeuneafrique.com/\n            title\nWed, 23 Oct 2024 14:27:00 UTC\nfr\nhourly\n1\n\n\nLes Africains de plus en plus exigeants vis-à-vis de leurs gouvernants : ce que révèle le rapport Mo Ibrahim\n\n\nhttps://www.jeuneafrique.com/1623433/politique/les-africains-de-plus-en-plus-exigeants-vis-a-vis-de-leurs-gouvernants-ce-que-revele-le-rapport-mo-ibrahim/\n\n2024-10-23T16:00:51+00:00\n\n\nMaÿlis Dudouet\n\nhttps://www.jeuneafrique.com/1623433/politique/les-africains-de-plus-en-plus-exigeants-vis-a-vis-de-leurs-gouvernants-ce-que-revele-le-rapport-mo-ibrahim/\n\nPeu de progrès sur la gouvernance, une insécurité croissante et l’État de droit qui recule dans de nombreux pays. Le dernier rapport de la Fondation Mo Ibrahim dresse un portrait peu flatteur des avancées sur le continent au
# ...

# %%
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=250,chunk_overlap=0)
doc_splits = text_splitter.split_documents(docs_list)
print(doc_splits)
# Out:
# [Document(metadata={'source': 'https://www.jeuneafrique.com/pays/cameroun/', 'title': 'Cameroun : suivez toute l’actualité du pays – Paul Biya – décryptages – infos en temps réel', 'description': 'Sur Jeune Afrique, retrouvez chaque jour l’actualité politique, économique, sportive, culturelle, sociétale du Cameroun, mais également des interviews exclusives et des focus sur des personnalités camerounaises', 'language': 'fr-FR'}, page_content="Cameroun : suivez toute l’actualité du pays – Paul Biya – décryptages – infos en temps réel\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\t\t\t\t\t\tOffres d'emploi\n\t\t\t\t\t\n\n\n\n\t\t\t\t\t\tAppels d'offres\n\t\t\t\t\t\n\n\n\n\t\t\t\t\t\tBoutique\n\t\t\t\t\t\n\n\n\n\t\t\t\t\t\tRecevoir nos newsletters\n\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\tTheAfricaReport\n\t\t\t\t\t\n\n\n\n\t\t\t\t\t\tAfricaBusiness+
# ...

# %%
os.environ["GOOGLE_API_KEY"] ="AIzaSyAivEeMYTxK5p5QNfqxSjrDTP2q-gyQwV0"

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
vectorstore = SKLearnVectorStore.from_documents(documents=doc_splits,embedding=embeddings)
retriever = vectorstore.as_retriever(k=10)

# %%
from langchain_community.document_loaders import UnstructuredHTMLLoader
loader = UnstructuredHTMLLoader("example_data/fake-content.html")

data = loader.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 from langchain_community.document_loaders import UnstructuredHTMLLoader
#       2 loader = UnstructuredHTMLLoader("example_data/fake-content.html")
# ----> 4 data = loader.load()
#
# File ~/Documents/INFO/.venv/lib/python3.11/site-packages/langchain_core/document_loaders/base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File ~/Documents/INFO/.venv/lib/python3.11/site-packages/langchain_community/document_loaders/unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
# ...

# %%
data

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/INFO/.venv/lib/python3.11/site-packages/langchain_community/document_loaders/unstructured.py:59, in UnstructuredBaseLoader.__init__(self, mode, post_processors, **unstructured_kwargs)
#      58 try:
# ---> 59     import unstructured  # noqa:F401
#      60 except ImportError:
#
# ModuleNotFoundError: No module named 'unstructured'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 loader = UnstructuredHTMLLoader("example_data/fake-content.html")
#
# File ~/Documents/INFO/.venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:216, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     214     warned = True
# ...

# %% [markdown]
# loader = UnstructuredHTMLLoader("example_data/fake-content.html")
